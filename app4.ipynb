# %% [markdown]
# ## This project implements a Retrieval-Augmented Generation (RAG) chatbot that dynamically fetches content from Wikipedia, processes it, and enables interactive question-answering using a custom prompt pipeline.

# %% [markdown]
# Key Features:
#
# Dynamic Knowledge Base: The chatbot loads a Wikipedia article based on the user’s first query and builds a context-aware retrieval system around it.
#
# Text Chunking & Embedding: The article is split into manageable chunks using LangChain’s RecursiveCharacterTextSplitter and embedded using HuggingFaceEmbeddings (all-MiniLM-L6-v2).
#
# Vector Database with Pinecone: Embeddings are stored in a Pinecone serverless index, enabling fast semantic search and retrieval.
#
# Groq LLM Integration: Uses llama3-70b-8192 via Groq for high-speed, cost-efficient inference with retrieved context.
#
# Custom Prompt-based RAG: Combines retrieved text and conversation history using a handcrafted prompt before passing it to the LLM.
#
# Chat Memory Support: Maintains conversational memory across turns using LangChain’s ConversationBufferMemory.

# %% [markdown]
# To use this application, you must provide your own API keys for:
#
# 🧠 Groq (for LLaMA3-based language generation)
# 📦 Pinecone (for vector similarity search and retrieval)

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (1.1.1)

# %%
# !pip install langchain langchain-community langchain-pinecone pinecone-client sentence-transformers
# Out:
# Requirement already satisfied: langchain in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-community in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-pinecone in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.2.8)
# Requirement already satisfied: pinecone-client in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (6.0.0)
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.3.68)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: langchain-tests<1.0.0,>=0.3.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-pinecone) (0.3.20)
# Requirement already satisfied: langchain-openai>=0.3.11 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-pinecone) (0.3.27)
# Requirement already satisfied: pytest<9,>=7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (8.4.1)
# Requirement already satisfied: pytest-asyncio<1,>=0.20 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.26.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Requirement already satisfied: syrupy<5,>=4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.1)
# Requirement already satisfied: pytest-socket<1,>=0.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pytest-benchmark in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (5.1.0)
# Requirement already satisfied: pytest-codspeed in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.2.0)
# Requirement already satisfied: pytest-recording in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.13.4)
# Requirement already satisfied: vcrpy>=7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (7.0.0)
# Requirement already satisfied: anyio in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.16.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.7.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.19.2)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.53.1-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: tqdm in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.7.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: scipy in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from sentence-transformers) (1.16.0)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.33.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Pillow in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from sentence-transformers) (11.3.0)
# Collecting filelock (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.21.2-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (1.93.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Collecting networkx (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: wrapt in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from vcrpy>=7.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: py-cpuinfo in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-benchmark->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (9.0.0)
# Requirement already satisfied: cffi>=1.17.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.1)
# Requirement already satisfied: rich>=13.8.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (14.0.0)
# Requirement already satisfied: pycparser in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from cffi>=1.17.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.1.2)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Using cached sentence_transformers-5.0.0-py3-none-any.whl (470 kB)
# Using cached transformers-4.53.1-py3-none-any.whl (10.8 MB)
# Using cached huggingface_hub-0.33.2-py3-none-any.whl (515 kB)
# Using cached tokenizers-0.21.2-cp39-abi3-win_amd64.whl (2.5 MB)
# Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Using cached torch-2.7.1-cp312-cp312-win_amd64.whl (216.1 MB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl (10.7 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: safetensors, networkx, joblib, fsspec, filelock, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ----------------------------------------  0/11 [safetensors]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    --- ------------------------------------  1/11 [networkx]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ------- --------------------------------  2/11 [joblib]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    ---------- -----------------------------  3/11 [fsspec]
#    -------------- -------------------------  4/11 [filelock]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
#    ------------------ ---------------------  5/11 [torch]
# ...
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    -------------------------------- -------  9/11 [transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ------------------------------------ --- 10/11 [sentence-transformers]
#    ---------------------------------------- 11/11 [sentence-transformers]
#
# Successfully installed filelock-3.18.0 fsspec-2025.5.1 huggingface-hub-0.33.2 joblib-1.5.1 networkx-3.5 safetensors-0.5.3 scikit-learn-1.7.0 sentence-transformers-5.0.0 tokenizers-0.21.2 torch-2.7.1 transformers-4.53.1

# %%
# !pip install langchain wikipedia langchain-pinecone tiktoken streamlit -U langchain_ollama
# Out:
# Requirement already satisfied: langchain in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.3.26)
# Requirement already satisfied: wikipedia in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-pinecone in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.2.8)
# Requirement already satisfied: tiktoken in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (0.9.0)
# Requirement already satisfied: streamlit in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (1.46.1)
# Collecting langchain_ollama
#   Using cached langchain_ollama-0.3.3-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.3.68)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from wikipedia) (4.13.4)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-pinecone) (2.3.1)
# Requirement already satisfied: langchain-tests<1.0.0,>=0.3.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-pinecone) (0.3.20)
# Requirement already satisfied: langchain-openai>=0.3.11 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-pinecone) (0.3.27)
# Requirement already satisfied: pytest<9,>=7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (8.4.1)
# Requirement already satisfied: pytest-asyncio<1,>=0.20 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.26.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.28.1)
# Requirement already satisfied: syrupy<5,>=4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.1)
# Requirement already satisfied: pytest-socket<1,>=0.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pytest-benchmark in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (5.1.0)
# Requirement already satisfied: pytest-codspeed in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.2.0)
# Requirement already satisfied: pytest-recording in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.13.4)
# Requirement already satisfied: vcrpy>=7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (7.0.0)
# Requirement already satisfied: anyio in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.16.0)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.7.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: aiohttp>=3.9.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.12.13)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: colorama>=0.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.4.6)
# Requirement already satisfied: iniconfig>=1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest<9,>=7->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.19.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (6.31.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.45.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Collecting ollama<1.0.0,>=0.4.8 (from langchain_ollama)
#   Using cached ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.26.0)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (1.93.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from openai<2.0.0,>=1.86.0->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: wrapt in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from vcrpy>=7.0->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from beautifulsoup4->wikipedia) (2.7)
# Requirement already satisfied: py-cpuinfo in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-benchmark->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (9.0.0)
# Requirement already satisfied: cffi>=1.17.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (1.17.1)
# Requirement already satisfied: rich>=13.8.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (14.0.0)
# Requirement already satisfied: pycparser in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from cffi>=1.17.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.1->pytest-codspeed->langchain-tests<1.0.0,>=0.3.7->langchain-pinecone) (0.1.2)
# Using cached langchain_ollama-0.3.3-py3-none-any.whl (21 kB)
# Using cached ollama-0.5.1-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, langchain_ollama
#
#    -------------------- ------------------- 1/2 [langchain_ollama]
#    ---------------------------------------- 2/2 [langchain_ollama]
#
# Successfully installed langchain_ollama-0.3.3 ollama-0.5.1

# %%
# !pip install -U langchain-huggingface
# Out:
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-0.3.0-py3-none-any.whl.metadata (996 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-huggingface) (0.3.68)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-huggingface) (0.21.2)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-huggingface) (0.33.2)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.14.1)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.0.0)
# Requirement already satisfied: filelock in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.5.1)
# Requirement already satisfied: requests in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from pydantic>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from requests->huggingface-hub>=0.30.2->langchain-huggingface) (2.5.0)
# Requirement already satisfied: colorama in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\91736\pycharmprojects\chatbot\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface) (1.3.1)
# Using cached langchain_huggingface-0.3.0-py3-none-any.whl (27 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.3.0

# %% [markdown]
# ## Imports

# %%
import os
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_huggingface import HuggingFaceEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
groq_api_key = os.getenv("GROQ_API_KEY")
pinecone_api_key = os.getenv("PINECONE_API_KEY")

# %% [markdown]
# ## Extracting Articles from Wikipedia

# %%
import wikipedia

def fetch_article(title):
    try:
        summary = wikipedia.page(title).content
        return summary
    except:
        return None

# %%
transcript = fetch_article("mahatma gandhi")

# %% [markdown]
# ## Text Chunking & Embedding

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
doc = Document(page_content=transcript)
chunks = splitter.split_documents([doc])

# %%
chunks[100]
# Out:
# Document(metadata={}, page_content='Friends and comrades, the light has gone out of our lives, and there is darkness everywhere, and I do not quite know what to tell you or how to say it. Our beloved leader, Bapu as we called him, the father of the nation, is no more. Perhaps I am wrong to say that; nevertheless, we will not see him again, as we have seen him for these many years, we will not run to him for advice or seek solace from him, and that is a terrible blow, not only for me, but for millions and millions in this country.')

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
vectors = embeddings.embed_query("who is gandhi?")
len(vectors)
# Out:
# 384

# %% [markdown]
# ## Creating a Pinecone vector database

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=pinecone_api_key)

index_name = "db"

if not pc.has_index(index_name):
    pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model":"llama-text-embed-v2",
            "field_map":{"text": "chunk_text"}
        }
    )

# %%
index = pc.Index(index_name)

# %%
from langchain_pinecone import PineconeVectorStore
vector_store = PineconeVectorStore(index=index, embedding=embeddings)

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key=groq_api_key,
    model_name="llama3-70b-8192"
)

# %%
# from langchain.prompts import PromptTemplate
#
# prompt = PromptTemplate(
#     template="""
# You are a helpful assistant.
# Answer ONLY from the provided transcript context.
# If the context is insufficient, just say you don't know.
#
# Context:
# {context}
#
# Question:
# {question}
# """,
#     input_variables=["context", "question"]
# )
#
# question = input("ask questions")
# retrieved_docs = retriever.invoke(question)
# context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
# final_prompt = prompt.format(context=context_text, question=question)
# response = llm.invoke(final_prompt)
#
# print("Bot:", response.content)

# %% [markdown]
# ## Creating a memory based chatbot

# %%
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

prompt = PromptTemplate(
    input_variables=["chat_history", "context", "question"],
    template="""
You are a helpful assistant having a conversation with a user.

Chat history:
{chat_history}

Use the following context from a transcript to answer:
{context}

Question:
{question}

If the context is not relevant, just say "I don't know."
""")

def rag_with_memory(question, retriever, llm, prompt_template, memory):
    retrieved_docs = retriever.invoke(question)
    context = "\n\n".join(doc.page_content for doc in retrieved_docs)

    chat_history = ""
    for msg in memory.chat_memory.messages:
        if msg.type == "human":
            chat_history += f"Human: {msg.content}\n"
        elif msg.type == "ai":
            chat_history += f"AI: {msg.content}\n"

    final_prompt = prompt_template.format(
        chat_history=chat_history.strip(),
        context=context,
        question=question
    )

    response = llm.invoke(final_prompt)

    memory.chat_memory.add_user_message(question)
    memory.chat_memory.add_ai_message(response.content)

    return response.content

# %%
print("🤖 Ask me anything! Type 'exit' to quit.\n")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        break
    answer = rag_with_memory(user_input, retriever, llm, prompt, memory)
    print("Bot:", answer)
# Out:
# 🤖 Ask me anything! Type 'exit' to quit.
